# %% [markdown]
# # Hyperparameter Tuning - Sub model 2

# %% [markdown]
# ## Load the Dataset 2

# %%
import pandas as pd

PTB_EPTB = pd.read_csv(r'..\..\Datasets\train\balanced\PTB_EPTB.csv')

# %% [markdown]
# ## Separate features and target

# %%
# Separate features and target in each dataset

X_PTB_EPTB = PTB_EPTB.drop(columns=['TB_Status'])
y_PTB_EPTB = PTB_EPTB['TB_Status']

# %% [markdown]
# ## Functions to select the best models with best hyperparameters

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt

# %%
# Define models and hyperparameter grids
models = {
    "Random Forest": {
        "model": RandomForestClassifier(),
        "params": {
            "n_estimators": [100, 200, 300],
            "max_depth": [None, 10, 20, 30],
            "min_samples_split": [2, 5, 10]
        }
    },
    "Gradient Boosting": {
        "model": GradientBoostingClassifier(),
        "params": {
            "learning_rate": [0.01, 0.1, 0.2],
            "n_estimators": [100, 200, 300],
            "max_depth": [3, 5, 7]
        }
    },
    "Naive Bayes": {
        "model": GaussianNB(),
        "params": {}
    },
    "LightGBM": {
        "model": LGBMClassifier(),
        "params": {
            "learning_rate": [0.01, 0.1, 0.2],
            "n_estimators": [100, 200, 300],
            "max_depth": [-1, 10, 20, 30]
        }
    },
    "XGBoost": {
        "model": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
        "params": {
            "learning_rate": [0.01, 0.1, 0.2],
            "n_estimators": [100, 200, 300],
            "max_depth": [3, 5, 7]
        }
    },
    "KNN": {
        "model": KNeighborsClassifier(),
        "params": {
            "n_neighbors": [3, 5, 7, 9],
            "weights": ["uniform", "distance"],
            "metric": ["euclidean", "manhattan"]
        }
    },
    "SVM": {
        "model": SVC(probability=True),
        "params": {
            "C": [0.1, 1, 10],
            "kernel": ["linear", "rbf"],
            "gamma": ["scale", "auto"]
        }
    }
}

# %%
def tune_and_evaluate(X_train, y_train, X_test, y_test, model_dict):
    results = []
    best_models = {}

    for name, model_info in model_dict.items():
        print(f"Tuning {name}...")

        # Apply GridSearchCV with early stopping for tree-based models
        if "early_stopping_rounds" in model_info["params"]:
            model_info["params"].pop("early_stopping_rounds")

        grid_search = GridSearchCV(model_info["model"], model_info["params"], cv=5, scoring='f1_weighted', verbose=1)
        grid_search.fit(X_train, y_train)

        best_model = grid_search.best_estimator_
        best_params = grid_search.best_params_
        best_models[name] = best_model

        # Evaluate on test data
        y_pred = best_model.predict(X_test)
        acc = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, average='weighted')
        recall = recall_score(y_test, y_pred, average='weighted')
        f1 = f1_score(y_test, y_pred, average='weighted')

        results.append({
            "Model": name,
            "Accuracy": acc,
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Best Hyperparameters": str(best_params)
        })

    return pd.DataFrame(results), best_models

def visualize_results(results_df, title):
    results_df.set_index("Model", inplace=True)
    results_df.drop(columns="Best Hyperparameters", inplace=True)  # Remove hyperparameters column for visualization
    results_df.plot(kind='bar', figsize=(12, 6), rot=0, colormap='viridis')
    plt.title(title)
    plt.ylabel("Score")
    plt.xlabel("Model")
    plt.legend(loc='lower right')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# ## Comparison between different algorithms for Sub model 2

# %%
# Load selected features for sub-model 2
selected_features_path = r'..\..\Saved_files\selected_features_PTB_EPTB.csv'
selected_features = pd.read_csv(selected_features_path)

# Example pipeline for TB_Type
X_train_TB_Type, X_test_TB_Type, y_train_TB_Type, y_test_TB_Type = train_test_split(
    X_PTB_EPTB, y_PTB_EPTB, test_size=0.2, random_state=42
)

# SMOTE for class imbalance
smote = SMOTE(random_state=42)
X_train_TB_Type_balanced, y_train_TB_Type_balanced = smote.fit_resample(X_train_TB_Type, y_train_TB_Type)

# Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_TB_Type_balanced)
X_test_scaled = scaler.transform(X_test_TB_Type)

# Label encoding (fit the encoder on the training data first, then transform both)
label_encoder_TB_Type = LabelEncoder()
y_train_encoded = label_encoder_TB_Type.fit_transform(y_train_TB_Type_balanced)
y_test_encoded = label_encoder_TB_Type.transform(y_test_TB_Type)

# Tune and evaluate
results_TB_Type, best_models_TB_Type = tune_and_evaluate(X_train_scaled, y_train_encoded, X_test_scaled, y_test_encoded, models)

# Identify and visualize the best model
best_model_overall = results_TB_Type.loc[results_TB_Type["F1 Score"].idxmax()]
print("\nOverall Best Model:")
print(f"Model: {best_model_overall['Model']}")
print(f"Accuracy: {best_model_overall['Accuracy']:.4f}")
print(f"Precision: {best_model_overall['Precision']:.4f}")
print(f"Recall: {best_model_overall['Recall']:.4f}")
print(f"F1 Score: {best_model_overall['F1 Score']:.4f}")
print(f"Best Hyperparameters: {best_model_overall['Best Hyperparameters']}")

visualize_results(results_TB_Type, "Model Performance Comparison for TB_Type")
# Out:
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#   File "c:\Users\dilan\anaconda3\envs\myenv\lib\subprocess.py", line 505, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "c:\Users\dilan\anaconda3\envs\myenv\lib\subprocess.py", line 951, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\dilan\anaconda3\envs\myenv\lib\subprocess.py", line 1436, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
# Tuning Random Forest...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Tuning Gradient Boosting...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Tuning Naive Bayes...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Tuning LightGBM...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Tuning XGBoost...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:32:47] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:33:21] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:33:54] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:34:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:35:01] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:35:34] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:36:39] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:37:45] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:38:51] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:39:56] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:41:01] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:42:37] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:44:14] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:45:51] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:47:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:49:04] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:50:23] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:51:46] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:53:05] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:54:28] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:55:49] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [03:58:12] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:00:46] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:03:12] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:05:43] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:08:12] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:11:37] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:15:14] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:18:42] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:22:14] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:25:45] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:27:28] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:29:09] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:30:48] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:32:33] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:34:17] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:37:23] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:40:26] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:43:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:46:36] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:49:43] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:53:54] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [04:58:07] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:02:17] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:06:38] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:10:57] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:11:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:11:57] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:12:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:12:57] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:13:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:14:15] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:15:03] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:15:52] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:16:41] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:17:30] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:18:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:19:33] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:20:36] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:21:38] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:22:41] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:23:29] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:24:19] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:25:07] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:25:56] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:26:44] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:27:48] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:28:55] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:30:00] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:31:06] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:32:12] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:33:29] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:34:49] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:36:09] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:37:29] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:38:50] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:39:44] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:40:40] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:41:35] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:42:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:43:29] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:44:39] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:45:51] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:47:04] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:48:16] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:49:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:50:53] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:52:19] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:53:45] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:55:11] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:56:40] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:57:04] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:57:29] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:57:53] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:58:18] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:58:44] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:59:20] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [05:59:57] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:00:34] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:01:11] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:01:49] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:02:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:03:15] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:03:58] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:04:42] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:05:26] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:06:02] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:06:38] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:07:12] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:07:46] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:08:20] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:09:04] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:09:51] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:10:36] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:11:21] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:12:07] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:12:58] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:13:51] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:14:43] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:15:36] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:16:28] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:17:06] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:17:43] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:18:22] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:19:00] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:19:38] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:20:26] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:21:16] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:22:05] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:22:55] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:23:46] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:24:41] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:25:35] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:26:32] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:27:29] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [06:28:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Tuning KNN...
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Tuning SVM...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
#
# Overall Best Model:
# Model: Random Forest
# Accuracy: 0.7722
# Precision: 0.7729
# Recall: 0.7722
# F1 Score: 0.7705
# Best Hyperparameters: {'max_depth': 30, 'min_samples_split': 5, 'n_estimators': 200}
