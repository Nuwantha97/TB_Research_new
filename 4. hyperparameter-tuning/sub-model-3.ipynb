# %% [markdown]
# # Hyperparameter Tuning - Sub model 3

# %% [markdown]
# ## Load the Dataset 3

# %%
import pandas as pd

ATB_LTB = pd.read_csv(r'..\..\Datasets\train\balanced\ATB_LTB.csv')

# %% [markdown]
# ## Separate features and target

# %%
# Separate features and target in each dataset

X_ATB_LTB = ATB_LTB.drop(columns=['TB_Status'])
y_ATB_LTB = ATB_LTB['TB_Status']

# %% [markdown]
# ## Functions to select the best models with best hyperparameters

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt

# %%
# Define models and hyperparameter grids
models = {
    "Random Forest": {
        "model": RandomForestClassifier(),
        "params": {
            "n_estimators": [100, 200, 300],
            "max_depth": [None, 10, 20, 30],
            "min_samples_split": [2, 5, 10]
        }
    },
    "Gradient Boosting": {
        "model": GradientBoostingClassifier(),
        "params": {
            "learning_rate": [0.01, 0.1, 0.2],
            "n_estimators": [100, 200, 300],
            "max_depth": [3, 5, 7]
        }
    },
    "Naive Bayes": {
        "model": GaussianNB(),
        "params": {}
    },
    "LightGBM": {
        "model": LGBMClassifier(),
        "params": {
            "learning_rate": [0.01, 0.1, 0.2],
            "n_estimators": [100, 200, 300],
            "max_depth": [-1, 10, 20, 30]
        }
    },
    "XGBoost": {
        "model": XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
        "params": {
            "learning_rate": [0.01, 0.1, 0.2],
            "n_estimators": [100, 200, 300],
            "max_depth": [3, 5, 7]
        }
    },
    "KNN": {
        "model": KNeighborsClassifier(),
        "params": {
            "n_neighbors": [3, 5, 7, 9],
            "weights": ["uniform", "distance"],
            "metric": ["euclidean", "manhattan"]
        }
    },
    "SVM": {
        "model": SVC(probability=True),
        "params": {
            "C": [0.1, 1, 10],
            "kernel": ["linear", "rbf"],
            "gamma": ["scale", "auto"]
        }
    }
}

# %%
def tune_and_evaluate(X_train, y_train, X_test, y_test, model_dict):
    results = []
    best_models = {}

    for name, model_info in model_dict.items():
        print(f"Tuning {name}...")

        # Apply GridSearchCV with early stopping for tree-based models
        if "early_stopping_rounds" in model_info["params"]:
            model_info["params"].pop("early_stopping_rounds")

        grid_search = GridSearchCV(model_info["model"], model_info["params"], cv=5, scoring='f1_weighted', verbose=1)
        grid_search.fit(X_train, y_train)

        best_model = grid_search.best_estimator_
        best_params = grid_search.best_params_
        best_models[name] = best_model

        # Evaluate on test data
        y_pred = best_model.predict(X_test)
        acc = accuracy_score(y_test, y_pred)
        precision = precision_score(y_test, y_pred, average='weighted')
        recall = recall_score(y_test, y_pred, average='weighted')
        f1 = f1_score(y_test, y_pred, average='weighted')

        results.append({
            "Model": name,
            "Accuracy": acc,
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Best Hyperparameters": str(best_params)
        })

    return pd.DataFrame(results), best_models

def visualize_results(results_df, title):
    results_df.set_index("Model", inplace=True)
    results_df.drop(columns="Best Hyperparameters", inplace=True)  # Remove hyperparameters column for visualization
    results_df.plot(kind='bar', figsize=(12, 6), rot=0, colormap='viridis')
    plt.title(title)
    plt.ylabel("Score")
    plt.xlabel("Model")
    plt.legend(loc='lower right')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %% [markdown]
# ## Comparison between different algorithms for Sub model 3

# %%
# Load selected features for sub-model 3
selected_features_path = r'..\..\Saved_files\selected_features_ATB_LTB.csv'
selected_features = pd.read_csv(selected_features_path)

# Example pipeline for TB_Stage
X_train_TB_Stage, X_test_TB_Stage, y_train_TB_Stage, y_test_TB_Stage = train_test_split(
    X_ATB_LTB, y_ATB_LTB, test_size=0.2, random_state=42
)

# SMOTE for class imbalance
smote = SMOTE(random_state=42)
X_train_TB_Stage_balanced, y_train_TB_Stage_balanced = smote.fit_resample(X_train_TB_Stage, y_train_TB_Stage)

# Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_TB_Stage_balanced)
X_test_scaled = scaler.transform(X_test_TB_Stage)

# Label encoding (fit the encoder on the training data first, then transform both)
label_encoder_TB_Stage = LabelEncoder()
y_train_encoded = label_encoder_TB_Stage.fit_transform(y_train_TB_Stage_balanced)
y_test_encoded = label_encoder_TB_Stage.transform(y_test_TB_Stage)

# Tune and evaluate
results_TB_Stage, best_models_TB_Stage = tune_and_evaluate(X_train_scaled, y_train_encoded, X_test_scaled, y_test_encoded, models)

# Identify and visualize the best model
best_model_overall = results_TB_Stage.loc[results_TB_Stage["F1 Score"].idxmax()]
print("\nOverall Best Model:")
print(f"Model: {best_model_overall['Model']}")
print(f"Accuracy: {best_model_overall['Accuracy']:.4f}")
print(f"Precision: {best_model_overall['Precision']:.4f}")
print(f"Recall: {best_model_overall['Recall']:.4f}")
print(f"F1 Score: {best_model_overall['F1 Score']:.4f}")
print(f"Best Hyperparameters: {best_model_overall['Best Hyperparameters']}")

visualize_results(results_TB_Stage, "Model Performance Comparison for TB_Stage")
# Out:
# Tuning Random Forest...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Tuning Gradient Boosting...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Tuning Naive Bayes...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Tuning LightGBM...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Tuning XGBoost...
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:13:01] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:13:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:13:53] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:14:19] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:14:46] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:15:13] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:16:04] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:16:54] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:17:46] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:18:37] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:19:29] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:20:44] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:21:57] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:23:12] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:24:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:25:43] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:26:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:27:22] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:28:11] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:29:05] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:29:58] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:31:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:33:00] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:34:33] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:36:12] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:37:51] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:39:57] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:42:05] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:44:15] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:46:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:48:48] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:49:42] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:50:34] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:51:27] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:52:22] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:53:19] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:54:56] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:56:32] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:58:09] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [12:59:52] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:01:37] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:03:48] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:06:03] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:08:17] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:10:36] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:12:59] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:13:19] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:13:39] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:13:59] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:14:19] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:14:40] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:15:08] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:15:36] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:16:05] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:16:34] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:17:05] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:17:38] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:18:10] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:18:44] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:19:18] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:19:53] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:20:21] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:20:48] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:21:15] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:21:44] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:22:14] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:22:49] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:23:24] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:23:59] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:24:36] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:25:16] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:25:55] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:26:35] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:27:14] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:27:57] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:28:41] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:29:09] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:29:37] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:30:04] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:30:34] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:31:05] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:31:42] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:32:17] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:32:52] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:33:30] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:34:10] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:34:51] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:35:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:36:11] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:36:54] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:37:38] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:37:53] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:38:07] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:38:22] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:38:37] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:38:53] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:39:12] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:39:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:39:50] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:40:10] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:40:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:40:54] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:41:18] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:41:41] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:42:06] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:42:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:42:49] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:43:09] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:43:28] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:43:48] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:44:08] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:44:32] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:44:56] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:45:19] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:45:44] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:46:08] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:46:36] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:47:05] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:47:33] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:48:01] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:48:31] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:48:50] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:49:10] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:49:29] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:49:49] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:50:10] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:50:34] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:50:58] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:51:22] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:51:46] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:52:12] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:52:40] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:53:08] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:53:37] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:54:07] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# c:\Users\dilan\anaconda3\envs\myenv\lib\site-packages\xgboost\core.py:158: UserWarning: [13:54:42] WARNING: C:\b\abs_90_bwj_86a\croot\xgboost-split_1724073762025\work\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Tuning KNN...
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Tuning SVM...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
#
# Overall Best Model:
# Model: Random Forest
# Accuracy: 0.8871
# Precision: 0.8936
# Recall: 0.8871
# F1 Score: 0.8836
# Best Hyperparameters: {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 200}
